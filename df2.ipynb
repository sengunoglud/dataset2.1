# %% [markdown]
# ## Import data

# %%
import pandas as pd

# %%
df = pd.read_csv('./6934_1593423955510.txt')

# %%
df.head(30)
# Out:
#     block1         .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 0   block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1   block1             Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2   block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3   block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 5   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 6   block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 7   block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 8   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 9   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 10  block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 11  block1             Kadın  Erkek  1  img     /images/male-1.png   Target2
# 12  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 13  block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 14  block1             Kadın  Erkek  1  img   /images/female-1.png   Target1
# 15  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 16  block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 17  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 18  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 19  block2  İyi  Kötü                1  txt              Güvenilir       İyi
# 20  block2  İyi  Kötü                1  txt              Ağırbaşlı       İyi
# 21  block2  İyi  Kötü                1  txt                Alıngan      Kötü
# 22  block2  İyi  Kötü                1  txt                  Cesur       İyi
# 23  block2  İyi  Kötü                1  txt               Çekingen      Kötü
# 24  block2  İyi  Kötü                1  txt               Çekingen      Kötü
# 25  block2  İyi  Kötü                1  txt               Duygusal      Kötü
# 26  block2  İyi  Kötü                1  txt                  Dobra       İyi
# 27  block2  İyi  Kötü                1  txt                  Dobra       İyi
# 28  block2  İyi  Kötü                1  txt                 Hassas      Kötü
# 29  block2  İyi  Kötü                1  txt               Kararsız      Kötü
#
#     1450.774999999794   True
# 0             350.165   True
# 1             434.745   True
# 2             410.260   True
# 3             462.010   True
# 4             531.130   True
# 5             358.805   True
# 6             411.755   True
# 7             483.070   True
# 8             387.385   True
# 9             371.165   True
# 10            387.170   True
# 11            435.640   True
# 12            403.960   True
# 13            360.490   True
# 14            414.165   True
# 15            526.370   True
# 16            438.460   True
# 17            403.855   True
# 18            412.945   True
# 19            716.185   True
# 20            404.495   True
# 21            589.235   True
# 22            594.205   True
# 23            733.145  False
# 24            373.215   True
# 25            521.560   True
# 26            754.375   True
# 27            382.160   True
# 28           3015.860   True
# 29            581.760   True

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#I checked out if any value is NaN

# %%
df.info
# Out:
# <bound method DataFrame.info of      block1         .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 0    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1    block1             Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2    block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4    block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# ..      ...  ...   ...    ...    ... ..  ...                    ...       ...
# 198  block7  İyi  Kötü  Kadın  Erkek  0  txt                Alıngan      Kötü
# 199  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-3.png   Target2
# 200  block7  İyi  Kötü  Kadın  Erkek  0  txt                 Hassas      Kötü
# 201  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-1.png   Target1
# 202  block7  İyi  Kötü  Kadın  Erkek  0  txt                  Dobra       İyi
#
#      1450.774999999794  True
# 0              350.165  True
# 1              434.745  True
# 2              410.260  True
# 3              462.010  True
# 4              531.130  True
# ..                 ...   ...
# 198            587.225  True
# 199            459.725  True
# 200            555.825  True
# 201            480.160  True
# 202            708.370  True
#
# [203 rows x 11 columns]>

# %%
print('Ndim: {}'.format(df.ndim))
print('Shape: {}'.format(df.shape))
print('Size: {}'.format(df.size))
print('Columns: {}'.format(df.columns))
# Out:
# Ndim: 2
# Shape: (203, 11)
# Size: 2233
# Columns: Index(['block1', ' ', ' .1', 'Kadın', 'Erkek', '1', 'img',
#        ' /images/male-3.png', ' Target2', 'Reaction Time (milliseconds)',
#        'Output'],
#       dtype='object')

# %%
df.rename(columns={'1450.774999999794': 'Reaction Time (milliseconds)', 'True': 'Output'} , inplace=True)

# %%
# I renamed the columns to see more clearly while i was working on dataset

# %%
df.block1.unique()
# Out:
# array(['block1', 'block2', 'block3', 'block4', 'block5', 'block6',
#        'block7'], dtype=object)

# %%
block1 = df.loc[df['block1'] == 'block1']
block2 = df.loc[df['block1'] == 'block2']
block3 = df.loc[df['block1'] == 'block3']
block4 = df.loc[df['block1'] == 'block4']
block5 = df.loc[df['block1'] == 'block5']
block6 = df.loc[df['block1'] == 'block6']
block7 = df.loc[df['block1'] == 'block7']

# %%
#as we can see, dataset which i worked includes 7 different blocks, this line divided my data into 7 parts

# %%
block1.head(10)
# Out:
#    block1     .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 0  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1  block1         Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2  block1         Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 5  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 6  block1         Kadın  Erkek  1  img   /images/female-2.png   Target1
# 7  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 8  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 9  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
#
#    Reaction Time (milliseconds)  Output
# 0                       350.165    True
# 1                       434.745    True
# 2                       410.260    True
# 3                       462.010    True
# 4                       531.130    True
# 5                       358.805    True
# 6                       411.755    True
# 7                       483.070    True
# 8                       387.385    True
# 9                       371.165    True

# %%
result1 = block1[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
#this line calculate mean/average of a given column

# %%
RT1 = result1

# %%
RT1
# Out:
# Reaction Time (milliseconds)    420.186579
# dtype: float64

# %%
block2.head(10)
# Out:
#     block1         .1 Kadın Erkek  1  img  /images/male-3.png  Target2  \
# 19  block2  İyi  Kötü              1  txt           Güvenilir      İyi
# 20  block2  İyi  Kötü              1  txt           Ağırbaşlı      İyi
# 21  block2  İyi  Kötü              1  txt             Alıngan     Kötü
# 22  block2  İyi  Kötü              1  txt               Cesur      İyi
# 23  block2  İyi  Kötü              1  txt            Çekingen     Kötü
# 24  block2  İyi  Kötü              1  txt            Çekingen     Kötü
# 25  block2  İyi  Kötü              1  txt            Duygusal     Kötü
# 26  block2  İyi  Kötü              1  txt               Dobra      İyi
# 27  block2  İyi  Kötü              1  txt               Dobra      İyi
# 28  block2  İyi  Kötü              1  txt              Hassas     Kötü
#
#     Reaction Time (milliseconds)  Output
# 19                       716.185    True
# 20                       404.495    True
# 21                       589.235    True
# 22                       594.205    True
# 23                       733.145   False
# 24                       373.215    True
# 25                       521.560    True
# 26                       754.375    True
# 27                       382.160    True
# 28                      3015.860    True

# %%
block2ed = ~block2.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
#this line drop out Falses from specified block2 dataframe

# %%
result2= block2[block2ed]

# %%
result2.head(10)
# Out:
#     block1         .1 Kadın Erkek  1  img  /images/male-3.png  Target2  \
# 19  block2  İyi  Kötü              1  txt           Güvenilir      İyi
# 20  block2  İyi  Kötü              1  txt           Ağırbaşlı      İyi
# 21  block2  İyi  Kötü              1  txt             Alıngan     Kötü
# 22  block2  İyi  Kötü              1  txt               Cesur      İyi
# 24  block2  İyi  Kötü              1  txt            Çekingen     Kötü
# 25  block2  İyi  Kötü              1  txt            Duygusal     Kötü
# 26  block2  İyi  Kötü              1  txt               Dobra      İyi
# 27  block2  İyi  Kötü              1  txt               Dobra      İyi
# 28  block2  İyi  Kötü              1  txt              Hassas     Kötü
# 29  block2  İyi  Kötü              1  txt            Kararsız     Kötü
#
#     Reaction Time (milliseconds)  Output
# 19                       716.185    True
# 20                       404.495    True
# 21                       589.235    True
# 22                       594.205    True
# 24                       373.215    True
# 25                       521.560    True
# 26                       754.375    True
# 27                       382.160    True
# 28                      3015.860    True
# 29                       581.760    True

# %%
RT2 = result2[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT2
# Out:
# Reaction Time (milliseconds)    642.71125
# dtype: float64

# %%
block3.head(10)
# Out:
#     block1         .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 41  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 42  block3  İyi  Kötü  Kadın  Erkek  1  txt                 Akıllı       İyi
# 43  block3  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 44  block3  İyi  Kötü  Kadın  Erkek  1  txt                 Hassas      Kötü
# 45  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 46  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 47  block3  İyi  Kötü  Kadın  Erkek  1  txt               Çekingen      Kötü
# 48  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 49  block3  İyi  Kötü  Kadın  Erkek  1  txt                   Kaba      Kötü
# 50  block3  İyi  Kötü  Kadın  Erkek  1  txt                   Kaba      Kötü
#
#     Reaction Time (milliseconds)  Output
# 41                      1424.005    True
# 42                       526.855    True
# 43                       473.315    True
# 44                       552.740    True
# 45                       398.200   False
# 46                       435.290    True
# 47                       532.855    True
# 48                       431.595    True
# 49                       474.625   False
# 50                       142.310    True

# %%
block3ed = ~block3.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result3= block3[block3ed]

# %%
result3.head(10)
# Out:
#     block1         .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 41  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 42  block3  İyi  Kötü  Kadın  Erkek  1  txt                 Akıllı       İyi
# 43  block3  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 44  block3  İyi  Kötü  Kadın  Erkek  1  txt                 Hassas      Kötü
# 46  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 47  block3  İyi  Kötü  Kadın  Erkek  1  txt               Çekingen      Kötü
# 48  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 50  block3  İyi  Kötü  Kadın  Erkek  1  txt                   Kaba      Kötü
# 51  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 53  block3  İyi  Kötü  Kadın  Erkek  1  txt               Başarılı       İyi
#
#     Reaction Time (milliseconds)  Output
# 41                      1424.005    True
# 42                       526.855    True
# 43                       473.315    True
# 44                       552.740    True
# 46                       435.290    True
# 47                       532.855    True
# 48                       431.595    True
# 50                       142.310    True
# 51                       409.255    True
# 53                       314.070    True

# %%
RT3 = result3[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT3
# Out:
# Reaction Time (milliseconds)    488.773
# dtype: float64

# %%
block4.head(10)
# Out:
#     block1         .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 67  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-3.png   Target2
# 68  block4  İyi  Kötü  Kadın  Erkek  1  txt                  Cesur       İyi
# 69  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 70  block4  İyi  Kötü  Kadın  Erkek  1  txt              Ağırbaşlı       İyi
# 71  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 72  block4  İyi  Kötü  Kadın  Erkek  1  txt                 Akıllı       İyi
# 73  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 74  block4  İyi  Kötü  Kadın  Erkek  1  txt              Ağırbaşlı       İyi
# 75  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 76  block4  İyi  Kötü  Kadın  Erkek  1  txt                Alıngan      Kötü
#
#     Reaction Time (milliseconds)  Output
# 67                       727.125    True
# 68                       495.190    True
# 69                       685.015    True
# 70                       718.590    True
# 71                       448.345    True
# 72                       465.225    True
# 73                       634.930    True
# 74                       446.110    True
# 75                       432.905    True
# 76                       472.020    True

# %%
block4ed = ~block4.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result4 = block4[block4ed]

# %%
result4.head(10)
# Out:
#     block1         .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 67  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-3.png   Target2
# 68  block4  İyi  Kötü  Kadın  Erkek  1  txt                  Cesur       İyi
# 69  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 70  block4  İyi  Kötü  Kadın  Erkek  1  txt              Ağırbaşlı       İyi
# 71  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 72  block4  İyi  Kötü  Kadın  Erkek  1  txt                 Akıllı       İyi
# 73  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 74  block4  İyi  Kötü  Kadın  Erkek  1  txt              Ağırbaşlı       İyi
# 75  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 76  block4  İyi  Kötü  Kadın  Erkek  1  txt                Alıngan      Kötü
#
#     Reaction Time (milliseconds)  Output
# 67                       727.125    True
# 68                       495.190    True
# 69                       685.015    True
# 70                       718.590    True
# 71                       448.345    True
# 72                       465.225    True
# 73                       634.930    True
# 74                       446.110    True
# 75                       432.905    True
# 76                       472.020    True

# %%
RT4 = result4[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT4
# Out:
# Reaction Time (milliseconds)    472.96425
# dtype: float64

# %%
block5ed = ~block5.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result5 = block5[block5ed]

# %%
RT5 = result5[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT5
# Out:
# Reaction Time (milliseconds)    461.06275
# dtype: float64

# %%
block6ed = ~block6.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result6 = block6[block6ed]

# %%
RT6 = result6[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT6
# Out:
# Reaction Time (milliseconds)    640.724
# dtype: float64

# %%
block7ed = ~block7.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result7 = block7[block7ed]

# %%
RT7 = result7[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT7
# Out:
# Reaction Time (milliseconds)    502.824625
# dtype: float64

# %%
final_result = {'RT': [RT1, RT2, RT3, RT4, RT5, RT6, RT6]}

# %%
final_result
# Out:
# {'RT': [Reaction Time (milliseconds)    420.186579
#   dtype: float64,
#   Reaction Time (milliseconds)    642.71125
#   dtype: float64,
#   Reaction Time (milliseconds)    488.773
#   dtype: float64,
#   Reaction Time (milliseconds)    472.96425
#   dtype: float64,
#   Reaction Time (milliseconds)    461.06275
#   dtype: float64,
#   Reaction Time (milliseconds)    640.724
#   dtype: float64,
#   Reaction Time (milliseconds)    640.724
#   dtype: float64]}

# %%
final_result_ = pd.DataFrame (final_result, columns = ['RT'])

# %%
#this line creates dataframe from final results to get average of the RT's

# %%
av_RT = final_result_.mean()

# %%
final_result_2 = {'RT': [RT1, RT2, RT3, RT4, RT5, RT6, RT6,a v_RT]}

# %%
final_result_2
# Out:
# {'RT': [Reaction Time (milliseconds)    420.186579
#   dtype: float64,
#   Reaction Time (milliseconds)    642.71125
#   dtype: float64,
#   Reaction Time (milliseconds)    488.773
#   dtype: float64,
#   Reaction Time (milliseconds)    472.96425
#   dtype: float64,
#   Reaction Time (milliseconds)    461.06275
#   dtype: float64,
#   Reaction Time (milliseconds)    640.724
#   dtype: float64,
#   Reaction Time (milliseconds)    640.724
#   dtype: float64,
#   RT    538.16369
#   dtype: float64]}

# %%
RT_df = pd.DataFrame.from_dict(final_result_2)

# %%
RT_df
# Out:
#                                                   RT
# 0  Reaction Time (milliseconds)    420.186579
# dty...
# 1  Reaction Time (milliseconds)    642.71125
# dtyp...
# 2  Reaction Time (milliseconds)    488.773
# dtype:...
# 3  Reaction Time (milliseconds)    472.96425
# dtyp...
# 4  Reaction Time (milliseconds)    461.06275
# dtyp...
# 5  Reaction Time (milliseconds)    640.724
# dtype:...
# 6  Reaction Time (milliseconds)    640.724
# dtype:...
# 7                     RT    538.16369
# dtype: float64

# %%
RT_df.to_csv(r'C:\Users\90505\Desktop\dataset2\RT_df.csv', index = False)

# %%
#this line exports the dataframe to outside

# %%
df.head(50)
# Out:
#     block1         .1  Kadın  Erkek  1  img     /images/male-3.png   Target2  \
# 0   block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1   block1             Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2   block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3   block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 5   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 6   block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 7   block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 8   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 9   block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 10  block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 11  block1             Kadın  Erkek  1  img     /images/male-1.png   Target2
# 12  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 13  block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 14  block1             Kadın  Erkek  1  img   /images/female-1.png   Target1
# 15  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 16  block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 17  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 18  block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# 19  block2  İyi  Kötü                1  txt              Güvenilir       İyi
# 20  block2  İyi  Kötü                1  txt              Ağırbaşlı       İyi
# 21  block2  İyi  Kötü                1  txt                Alıngan      Kötü
# 22  block2  İyi  Kötü                1  txt                  Cesur       İyi
# 23  block2  İyi  Kötü                1  txt               Çekingen      Kötü
# 24  block2  İyi  Kötü                1  txt               Çekingen      Kötü
# 25  block2  İyi  Kötü                1  txt               Duygusal      Kötü
# 26  block2  İyi  Kötü                1  txt                  Dobra       İyi
# 27  block2  İyi  Kötü                1  txt                  Dobra       İyi
# 28  block2  İyi  Kötü                1  txt                 Hassas      Kötü
# 29  block2  İyi  Kötü                1  txt               Kararsız      Kötü
# 30  block2  İyi  Kötü                1  txt              Güvenilir       İyi
# 31  block2  İyi  Kötü                1  txt               Başarılı       İyi
# 32  block2  İyi  Kötü                1  txt               Kararsız      Kötü
# 33  block2  İyi  Kötü                1  txt              Ağırbaşlı       İyi
# 34  block2  İyi  Kötü                1  txt              Ağırbaşlı       İyi
# 35  block2  İyi  Kötü                1  txt              Ağırbaşlı       İyi
# 36  block2  İyi  Kötü                1  txt                 Akıllı       İyi
# 37  block2  İyi  Kötü                1  txt                   Kaba      Kötü
# 38  block2  İyi  Kötü                1  txt             Dedikoducu      Kötü
# 39  block2  İyi  Kötü                1  txt                 Hassas      Kötü
# 40  block2  İyi  Kötü                1  txt             Dedikoducu      Kötü
# 41  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 42  block3  İyi  Kötü  Kadın  Erkek  1  txt                 Akıllı       İyi
# 43  block3  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 44  block3  İyi  Kötü  Kadın  Erkek  1  txt                 Hassas      Kötü
# 45  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 46  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 47  block3  İyi  Kötü  Kadın  Erkek  1  txt               Çekingen      Kötü
# 48  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 49  block3  İyi  Kötü  Kadın  Erkek  1  txt                   Kaba      Kötü
#
#     Reaction Time (milliseconds)  Output
# 0                        350.165    True
# 1                        434.745    True
# 2                        410.260    True
# 3                        462.010    True
# 4                        531.130    True
# 5                        358.805    True
# 6                        411.755    True
# 7                        483.070    True
# 8                        387.385    True
# 9                        371.165    True
# 10                       387.170    True
# 11                       435.640    True
# 12                       403.960    True
# 13                       360.490    True
# 14                       414.165    True
# 15                       526.370    True
# 16                       438.460    True
# 17                       403.855    True
# 18                       412.945    True
# 19                       716.185    True
# 20                       404.495    True
# 21                       589.235    True
# 22                       594.205    True
# 23                       733.145   False
# 24                       373.215    True
# 25                       521.560    True
# 26                       754.375    True
# 27                       382.160    True
# 28                      3015.860    True
# 29                       581.760    True
# 30                       566.040    True
# 31                       452.240    True
# 32                       484.915    True
# 33                       542.905   False
# 34                       311.360    True
# 35                       594.800    True
# 36                       478.315    True
# 37                       531.480    True
# 38                       571.550    True
# 39                       447.015    True
# 40                       483.460    True
# 41                      1424.005    True
# 42                       526.855    True
# 43                       473.315    True
# 44                       552.740    True
# 45                       398.200   False
# 46                       435.290    True
# 47                       532.855    True
# 48                       431.595    True
# 49                       474.625   False

# %% [markdown]
# ## Filtering

# %%
df.columns = df.columns.str.replace('/images/male-3.png','X')

# %%
df
# Out:
#      block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 0    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1    block1             Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2    block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4    block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# ..      ...  ...   ...    ...    ... ..  ...                    ...       ...
# 198  block7  İyi  Kötü  Kadın  Erkek  0  txt                Alıngan      Kötü
# 199  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-3.png   Target2
# 200  block7  İyi  Kötü  Kadın  Erkek  0  txt                 Hassas      Kötü
# 201  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-1.png   Target1
# 202  block7  İyi  Kötü  Kadın  Erkek  0  txt                  Dobra       İyi
#
#      Reaction Time (milliseconds)  Output
# 0                         350.165    True
# 1                         434.745    True
# 2                         410.260    True
# 3                         462.010    True
# 4                         531.130    True
# ..                            ...     ...
# 198                       587.225    True
# 199                       459.725    True
# 200                       555.825    True
# 201                       480.160    True
# 202                       708.370    True
#
# [203 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['block1', ' ', ' .1', 'Kadın', 'Erkek', '1', 'img', ' X', ' Target2',
#        'Reaction Time (milliseconds)', 'Output'],
#       dtype='object')

# %%
df = df.rename(columns={' X': 'X'})

# %%
#I got some errors because of the name of column,then i changed

# %%
df.columns
# Out:
# Index(['block1', ' ', ' .1', 'Kadın', 'Erkek', '1', 'img', 'X', ' Target2',
#        'Reaction Time (milliseconds)', 'Output'],
#       dtype='object')

# %%
df.X.unique()
# Out:
# array([' /images/male-3.png', ' /images/female-3.png',
#        ' /images/female-2.png', ' /images/male-2.png',
#        ' /images/male-1.png', ' /images/female-1.png', ' Güvenilir',
#        ' Ağırbaşlı', ' Alıngan', ' Cesur', ' Çekingen', ' Duygusal',
#        ' Dobra', ' Hassas', ' Kararsız', ' Başarılı', ' Akıllı', ' Kaba',
#        ' Dedikoducu'], dtype=object)

# %%
#this line controls the values on a specific column

# %%
df_gender = df.loc[df['X'].isin([' /images/male-3.png', ' /images/female-3.png',
       ' /images/female-2.png', ' /images/male-2.png',
       ' /images/male-1.png', ' /images/female-1.png'])]

# %%
df_gender
# Out:
#      block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 0    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1    block1             Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2    block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4    block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# ..      ...  ...   ...    ...    ... ..  ...                    ...       ...
# 191  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 194  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 197  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
# 199  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-3.png   Target2
# 201  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-1.png   Target1
#
#      Reaction Time (milliseconds)  Output
# 0                         350.165    True
# 1                         434.745    True
# 2                         410.260    True
# 3                         462.010    True
# 4                         531.130    True
# ..                            ...     ...
# 191                       527.385    True
# 194                       421.425    True
# 197                       440.545    True
# 199                       459.725    True
# 201                       480.160    True
#
# [107 rows x 11 columns]

# %% [markdown]
# ## Add a gender column

# %%
def get_gender(gender):
    return gender.split('/')[2].split('-')[0]
df_gender['Gender'] = df_gender['X'].apply(lambda x: get_gender(x))
# Out:
# D:\Users\90505\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# this function picks the characters between second / to first -

# %%
df_gender
# Out:
#      block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 0    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1    block1             Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2    block1             Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3    block1             Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4    block1             Kadın  Erkek  1  img     /images/male-2.png   Target2
# ..      ...  ...   ...    ...    ... ..  ...                    ...       ...
# 191  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 194  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 197  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
# 199  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-3.png   Target2
# 201  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-1.png   Target1
#
#      Reaction Time (milliseconds)  Output  Gender
# 0                         350.165    True    male
# 1                         434.745    True  female
# 2                         410.260    True  female
# 3                         462.010    True    male
# 4                         531.130    True    male
# ..                            ...     ...     ...
# 191                       527.385    True  female
# 194                       421.425    True  female
# 197                       440.545    True  female
# 199                       459.725    True    male
# 201                       480.160    True  female
#
# [107 rows x 12 columns]

# %%
block1_2 = df_gender.loc[df_gender['block1'] == 'block1']
block2_2 = df_gender.loc[df_gender['block1'] == 'block2']
block3_2 = df_gender.loc[df_gender['block1'] == 'block3']
block4_2 = df_gender.loc[df_gender['block1'] == 'block4']
block5_2 = df_gender.loc[df_gender['block1'] == 'block5']
block6_2 = df_gender.loc[df_gender['block1'] == 'block6']
block7_2 = df_gender.loc[df_gender['block1'] == 'block7']

# %%
block1_2
# Out:
#     block1     .1  Kadın  Erkek  1  img                      X   Target2  \
# 0   block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1   block1         Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2   block1         Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3   block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4   block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 5   block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 6   block1         Kadın  Erkek  1  img   /images/female-2.png   Target1
# 7   block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 8   block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 9   block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 10  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 11  block1         Kadın  Erkek  1  img     /images/male-1.png   Target2
# 12  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 13  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 14  block1         Kadın  Erkek  1  img   /images/female-1.png   Target1
# 15  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 16  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 17  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
# 18  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
#
#     Reaction Time (milliseconds)  Output  Gender
# 0                        350.165    True    male
# 1                        434.745    True  female
# 2                        410.260    True  female
# 3                        462.010    True    male
# 4                        531.130    True    male
# 5                        358.805    True    male
# 6                        411.755    True  female
# 7                        483.070    True    male
# 8                        387.385    True    male
# 9                        371.165    True    male
# 10                       387.170    True    male
# 11                       435.640    True    male
# 12                       403.960    True    male
# 13                       360.490    True    male
# 14                       414.165    True  female
# 15                       526.370    True    male
# 16                       438.460    True    male
# 17                       403.855    True    male
# 18                       412.945    True    male

# %%
block1_2ed = ~block1_2.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result1_2 = block1_2[block1_2ed]

# %%
result1_2.head(5)
# Out:
#    block1     .1  Kadın  Erkek  1  img                      X   Target2  \
# 0  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 1  block1         Kadın  Erkek  1  img   /images/female-3.png   Target1
# 2  block1         Kadın  Erkek  1  img   /images/female-2.png   Target1
# 3  block1         Kadın  Erkek  1  img     /images/male-3.png   Target2
# 4  block1         Kadın  Erkek  1  img     /images/male-2.png   Target2
#
#    Reaction Time (milliseconds)  Output  Gender
# 0                       350.165    True    male
# 1                       434.745    True  female
# 2                       410.260    True  female
# 3                       462.010    True    male
# 4                       531.130    True    male

# %%
RT1_2 = result1_2[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT1_2
# Out:
# Reaction Time (milliseconds)    420.186579
# dtype: float64

# %%
##block2'de cinsiyet değeri yoktu. o yüzden block2_2de değer bulamadık.

# %%
block3_2
# Out:
#     block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 41  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 43  block3  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 45  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 46  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 48  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 51  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 54  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 56  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 59  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 63  block3  İyi  Kötü  Kadın  Erkek  1  img     /images/male-1.png   Target2
# 65  block3  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
#
#     Reaction Time (milliseconds)  Output  Gender
# 41                      1424.005    True  female
# 43                       473.315    True    male
# 45                       398.200   False  female
# 46                       435.290    True  female
# 48                       431.595    True  female
# 51                       409.255    True  female
# 54                       645.335    True  female
# 56                       539.420    True  female
# 59                       543.400    True  female
# 63                       432.315    True    male
# 65                       427.530    True    male

# %%
block3_2ed = ~block3_2.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result3_2 = block3_2[block3_2ed]

# %%
result3_2.head(5)
# Out:
#     block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 41  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 43  block3  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 46  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 48  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 51  block3  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
#
#     Reaction Time (milliseconds)  Output  Gender
# 41                      1424.005    True  female
# 43                       473.315    True    male
# 46                       435.290    True  female
# 48                       431.595    True  female
# 51                       409.255    True  female

# %%
RT3_2 = result3_2[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT3_2
# Out:
# Reaction Time (milliseconds)    576.146
# dtype: float64

# %%
block4_2
# Out:
#      block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 67   block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-3.png   Target2
# 69   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 71   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 73   block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 75   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 77   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 79   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 81   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 83   block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 85   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 87   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 88   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 90   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 92   block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-3.png   Target2
# 94   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 95   block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 98   block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 100  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 103  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 106  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-3.png   Target2
# 108  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-2.png   Target1
# 110  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-1.png   Target2
#
#      Reaction Time (milliseconds)  Output  Gender
# 67                        727.125    True    male
# 69                        685.015    True  female
# 71                        448.345    True  female
# 73                        634.930    True    male
# 75                        432.905    True  female
# 77                        417.950    True  female
# 79                        399.140    True  female
# 81                        375.100    True  female
# 83                        437.785    True    male
# 85                        491.900    True  female
# 87                        519.245   False  female
# 88                        280.820    True  female
# 90                        403.055    True  female
# 92                        522.010    True    male
# 94                        563.145   False  female
# 95                        327.285    True  female
# 98                        469.475    True    male
# 100                       453.575    True  female
# 103                       610.365    True  female
# 106                       480.000    True    male
# 108                       482.480    True  female
# 110                       449.600    True    male

# %%
block4_2ed = ~block4_2.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result4_2 = block4_2[block4_2ed]

# %%
result4_2.head(5)
# Out:
#     block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 67  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-3.png   Target2
# 69  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-1.png   Target1
# 71  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
# 73  block4  İyi  Kötü  Kadın  Erkek  1  img     /images/male-2.png   Target2
# 75  block4  İyi  Kötü  Kadın  Erkek  1  img   /images/female-3.png   Target1
#
#     Reaction Time (milliseconds)  Output  Gender
# 67                       727.125    True    male
# 69                       685.015    True  female
# 71                       448.345    True  female
# 73                       634.930    True    male
# 75                       432.905    True  female

# %%
RT4_2 = result4_2[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT4_2
# Out:
# Reaction Time (milliseconds)    476.443
# dtype: float64

# %%
block5_2
# Out:
#      block1     .1  Kadın  Erkek  1  img                      X   Target2  \
# 113  block5         Kadın  Erkek  0  img     /images/male-2.png   Target2
# 114  block5         Kadın  Erkek  0  img     /images/male-1.png   Target2
# 115  block5         Kadın  Erkek  0  img   /images/female-1.png   Target1
# 116  block5         Kadın  Erkek  0  img     /images/male-2.png   Target2
# 117  block5         Kadın  Erkek  0  img     /images/male-3.png   Target2
# 118  block5         Kadın  Erkek  0  img     /images/male-3.png   Target2
# 119  block5         Kadın  Erkek  0  img     /images/male-3.png   Target2
# 120  block5         Kadın  Erkek  0  img     /images/male-3.png   Target2
# 121  block5         Kadın  Erkek  0  img   /images/female-3.png   Target1
# 122  block5         Kadın  Erkek  0  img     /images/male-2.png   Target2
# 123  block5         Kadın  Erkek  0  img     /images/male-2.png   Target2
# 124  block5         Kadın  Erkek  0  img   /images/female-1.png   Target1
# 125  block5         Kadın  Erkek  0  img     /images/male-2.png   Target2
# 126  block5         Kadın  Erkek  0  img   /images/female-1.png   Target1
# 127  block5         Kadın  Erkek  0  img     /images/male-1.png   Target2
# 128  block5         Kadın  Erkek  0  img   /images/female-3.png   Target1
# 129  block5         Kadın  Erkek  0  img   /images/female-1.png   Target1
# 130  block5         Kadın  Erkek  0  img     /images/male-1.png   Target2
# 131  block5         Kadın  Erkek  0  img     /images/male-1.png   Target2
# 132  block5         Kadın  Erkek  0  img     /images/male-1.png   Target2
# 133  block5         Kadın  Erkek  0  img     /images/male-2.png   Target2
# 134  block5         Kadın  Erkek  0  img     /images/male-1.png   Target2
#
#      Reaction Time (milliseconds)  Output  Gender
# 113                      1464.055    True    male
# 114                       435.270    True    male
# 115                       443.375    True  female
# 116                       434.825    True    male
# 117                       539.165   False    male
# 118                       356.415    True    male
# 119                       317.710    True    male
# 120                       333.965    True    male
# 121                       417.250    True  female
# 122                       495.975    True    male
# 123                       361.040    True    male
# 124                       447.145    True  female
# 125                       458.505    True    male
# 126                       524.155    True  female
# 127                       449.230    True    male
# 128                       385.585    True  female
# 129                       408.970    True  female
# 130                       407.470   False    male
# 131                       217.930    True    male
# 132                       478.045    True    male
# 133                       437.295    True    male
# 134                       354.515    True    male

# %%
block5_2ed = ~block5_2.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result5_2 = block5_2[block5_2ed]

# %%
RT5_2 = result5_2[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT5_2
# Out:
# Reaction Time (milliseconds)    461.06275
# dtype: float64

# %%
block6_2
# Out:
#      block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 135  block6  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 137  block6  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 138  block6  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 140  block6  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 142  block6  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
# 144  block6  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 145  block6  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 147  block6  İyi  Kötü  Kadın  Erkek  0  img     /images/male-2.png   Target2
# 149  block6  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
# 151  block6  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 153  block6  İyi  Kötü  Kadın  Erkek  0  img     /images/male-2.png   Target2
# 155  block6  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
#
#      Reaction Time (milliseconds)  Output  Gender
# 135                       943.815    True    male
# 137                       362.665   False  female
# 138                       335.890    True  female
# 140                       396.635    True    male
# 142                       604.230    True  female
# 144                       808.090   False    male
# 145                      1017.320    True    male
# 147                       515.870    True    male
# 149                       554.630    True  female
# 151                       448.035    True  female
# 153                       403.185    True    male
# 155                       517.515    True  female

# %%
block6_2ed = ~block6_2.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result6_2 = block6_2[block6_2ed]

# %%
RT6_2 = result6_2[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT6_2
# Out:
# Reaction Time (milliseconds)    573.7125
# dtype: float64

# %%
block7_2
# Out:
#      block1         .1  Kadın  Erkek  1  img                      X   Target2  \
# 157  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 159  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
# 161  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-3.png   Target2
# 163  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 165  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 167  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-2.png   Target2
# 168  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-2.png   Target2
# 171  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-2.png   Target2
# 173  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 175  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 177  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-2.png   Target2
# 180  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-1.png   Target1
# 182  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 184  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-1.png   Target2
# 186  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-1.png   Target1
# 189  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
# 191  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 194  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-2.png   Target1
# 197  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-3.png   Target1
# 199  block7  İyi  Kötü  Kadın  Erkek  0  img     /images/male-3.png   Target2
# 201  block7  İyi  Kötü  Kadın  Erkek  0  img   /images/female-1.png   Target1
#
#      Reaction Time (milliseconds)  Output  Gender
# 157                       837.300    True    male
# 159                       472.220    True  female
# 161                       464.985    True    male
# 163                       587.320    True    male
# 165                       505.570    True  female
# 167                       371.280   False    male
# 168                       221.345    True    male
# 171                       424.025    True    male
# 173                       413.680    True    male
# 175                       371.180    True    male
# 177                       351.105    True    male
# 180                       493.355    True  female
# 182                       532.575    True    male
# 184                       438.465    True    male
# 186                       478.385    True  female
# 189                       463.790    True  female
# 191                       527.385    True  female
# 194                       421.425    True  female
# 197                       440.545    True  female
# 199                       459.725    True    male
# 201                       480.160    True  female

# %%
block7_2ed = ~block7_2.apply(lambda series: series.astype(str).str.contains('False')).any(axis=1)

# %%
result7_2 = block7_2[block7_2ed]

# %%
RT7_2 = result7_2[['Reaction Time (milliseconds)']].mean(axis=0)

# %%
RT7_2
# Out:
# Reaction Time (milliseconds)    469.227
# dtype: float64

# %%
RT6_2
# Out:
# Reaction Time (milliseconds)    573.7125
# dtype: float64

# %%
data_rt = {'RT':['RT1_2', 'RT2_2', 'RT3_2', 'RT4_2', 'RT5_2', 'RT6_2', 'RT7_2'], 'Milliseconds':[420.186579, 'imagenotfound', 576.146, 476.443, 461.06275, 573.7125, 469.227]}

# %%
result_df2 = pd.DataFrame(data_rt)

# %%
result_df2
# Out:
#       RT   Milliseconds
# 0  RT1_2        420.187
# 1  RT2_2  imagenotfound
# 2  RT3_2        576.146
# 3  RT4_2        476.443
# 4  RT5_2        461.063
# 5  RT6_2        573.712
# 6  RT7_2        469.227

# %%
result_df2.to_csv(r'C:\Users\90505\Desktop\dataset2\result_df2.csv', index = False)
